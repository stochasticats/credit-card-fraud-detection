# %% [markdown]
# <a href="https://colab.research.google.com/github/stochasticats/credit-card-fraud-detection/blob/master/Plant_Pathology_FGVC7_Identifying_foliar_disease_with_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plant Pathology 2020 - FGVC7
# Identify the category of foliar diseases in apple trees
#
# Kaggle competition - https://www.kaggle.com/c/plant-pathology-2020-fgvc7/submit

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
print(tf.__version__)
import os
import shutil
import matplotlib.pyplot as plt
# Out:
# 2.2.0-rc3

# %% [markdown]
# #Loading Data and Preprocessing
# Here we load the data and take a look at what we're dealing with.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -uq "/content/drive/My Drive/plant-pathology-2020-fgvc7.zip"

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

target = train[['healthy', 'multiple_diseases', 'rust', 'scab']]
test_ids = test['image_id']

train_len = train.shape[0]
test_len = test.shape[0]

train.describe()
# Out:
#            healthy  multiple_diseases         rust         scab
# count  1821.000000        1821.000000  1821.000000  1821.000000
# mean      0.283361           0.049973     0.341571     0.325096
# std       0.450754           0.217948     0.474367     0.468539
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           0.000000     0.000000     0.000000
# 50%       0.000000           0.000000     0.000000     0.000000
# 75%       1.000000           0.000000     1.000000     1.000000
# max       1.000000           1.000000     1.000000     1.000000

# %%
print("Shape of train data: " + str(train.shape))
print("Shape of test data: " + str(test.shape))
# Out:
# Shape of train data: (1821, 5)
# Shape of test data: (1821, 1)

# %%
train_len = train.shape[0]
test_len = test.shape[0]
print(train_len)
print(test_len)
# Out:
# 1821
# 1821

# %% [markdown]
# Let's see the distribution of images in terms of the targets/labels.

# %%
print(train.describe())
print(test.describe())
# Out:
#            healthy  multiple_diseases         rust         scab
# count  1821.000000        1821.000000  1821.000000  1821.000000
# mean      0.283361           0.049973     0.341571     0.325096
# std       0.450754           0.217948     0.474367     0.468539
# min       0.000000           0.000000     0.000000     0.000000
# 25%       0.000000           0.000000     0.000000     0.000000
# 50%       0.000000           0.000000     0.000000     0.000000
# 75%       1.000000           0.000000     1.000000     1.000000
# max       1.000000           1.000000     1.000000     1.000000
#         image_id
# count       1821
# unique      1821
# top     Test_793
# freq           1

# %% [markdown]
# Ah, we see the multiple_diseases label has drastically less images than the rest of the labels. Once we load the images in raw data form, we'll use scikitlearn to randomly over sample so we can fix this class imbalance.
#
# Now let's load the image data.

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from tqdm.notebook import tqdm

path = '/content/images/'
size = 224

train_images = np.ndarray(shape=(train_len, size, size, 3))
for i in tqdm(range(train_len)):
  img = load_img(path + f'Train_{i}.jpg', target_size=(size, size))
  train_images[i] = np.uint8(img_to_array(img))

test_images = np.ndarray(shape=(test_len, size, size, 3))
for i in tqdm(range(test_len)):
  img = load_img(path + f'Test_{i}.jpg', target_size=(size, size))
  test_images[i] = np.uint8(img_to_array(img))

train_images.shape, test_images.shape
# Out:
# Using TensorFlow backend.
# HBox(children=(IntProgress(value=0, max=1821), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1821), HTML(value='')))
# ((1821, 224, 224, 3), (1821, 224, 224, 3))

# %%
print(train_images.shape)
print(test_images.shape)
# Out:
# (1821, 224, 224, 3)
# (1821, 224, 224, 3)

# %% [markdown]
# Here we see the images are in raw data form, with three matrices for RGB format. We'll rescale later on as well.

# %% [markdown]
# Let's take a look at what the images look like.

# %%
for i in range(4):
	plt.subplot(220 + 1 + i)
	plt.title(train['image_id'][i])
	plt.imshow(np.uint8(train_images[i]))
plt.show()
plt.savefig('train_images.png')

# %%
for i in range(4):
	plt.subplot(220 + 1 + i)
	plt.title(test['image_id'][i])
	plt.imshow(np.uint8(test_images[i]))
plt.show()
plt.savefig('test_images.png')

# %% [markdown]
# Let's split out data into train and test sets for the model.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(train_images, target.to_numpy(), test_size=0.1, random_state=289) 

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1638, 224, 224, 3), (183, 224, 224, 3), (1638, 4), (183, 4))

# %% [markdown]
# Now use RandomOverSampler to fix our class imbalance in the multiple diseases class.

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=289)

x_train, y_train = ros.fit_resample(x_train.reshape((-1, size * size * 3)), y_train)
x_train = x_train.reshape((-1, size, size, 3))
x_train.shape, y_train.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# ((2240, 224, 224, 3), (2240, 4))

# %%
import gc

del train_images
gc.collect()
# Out:
# 15866

# %% [markdown]
# Now we prepare the data for going into a Keras deep learning model. Here I use the ImageDataGenerator to also give us more images by using the parameters to rotate, horizontally flip, and vertically flip. Also the image is rescaled by 1/255 to normalize the raw data so that the activation functions work properly.

# %%
from keras_preprocessing.image import ImageDataGenerator

batch_size = 8

train_datagen = ImageDataGenerator(samplewise_center = True,
                                   samplewise_std_normalization = True,
                                   horizontal_flip = True,
                                   vertical_flip = True,
                                   rotation_range=20)

train_generator = train_datagen.flow(
    x = x_train, 
    y = y_train,
    batch_size = batch_size)

validation_datagen = ImageDataGenerator(samplewise_center = True,
                                        samplewise_std_normalization = True)

validation_generator = validation_datagen.flow(
    x = x_test, 
    y = y_test,
    batch_size = batch_size)

# %%
idx = np.random.randint(8)
x, y = train_generator.__getitem__(idx)
plt.title(y[idx])
plt.imshow(x[idx])
plt.savefig('processed_img.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Model
# Let's create the model. Here I build a custom model consisting of convolution layers of ascending filter size, a flatten, and 2 dense layers with the last activation function being the softmax so we can predict between four classes.

# %%
def create_model():
    pre_trained = tf.keras.applications.MobileNet(input_shape=(size, size, 3), weights='imagenet', include_top=False, dropout = 0.3)
    for layer in pre_trained.layers:
      layer.trainable = False
    
    #pretrained_model = tf.keras.applications.mobilenet.MobileNet(input_shape=(SIZE,SIZE,3), include_top=False)
    model = tf.keras.Sequential([
      pre_trained,
      #tf.keras.layers.Conv2D(32, (3,3), input_shape=(size, size, 3)),
      #tf.keras.layers.BatchNormalization(),
      #tf.keras.layers.Activation('relu'),
      #tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),
      #tf.keras.layers.Conv2D(64, (3,3)),
      #tf.keras.layers.BatchNormalization(),
      #tf.keras.layers.Activation('relu'),
      #tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),
      #tf.keras.layers.Conv2D(128, (3,3)),
      #tf.keras.layers.BatchNormalization(),
      #tf.keras.layers.Activation('relu'),
      #tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(4, activation='softmax')
      ])
    model.compile(
        loss = 'kullback_leibler_divergence', 
        optimizer = 'adam', 
        metrics = ['accuracy'])
    return model

model = create_model()

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Model)   (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 200708
# =================================================================
# Total params: 3,429,572
# Trainable params: 200,708
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
epochs = 50
steps_per_epoch = x_train.shape[0] // batch_size
validation_steps = x_test.shape[0] // batch_size
print(steps_per_epoch)
# Out:
# 280

# %% [markdown]
# Let's set up some callbacks.
# Callbacks:
#
# **EarlyStopping** - stop early if the validation loss has stopped improving
#
# **ModelCheckpoint** - save the model every epoch and save the best weights
#
# **ReduceLROnPlateau** - reduce learning rate when validation loss has stopped improving
#
# **LearningRateScheduler** - set learning rate to ramp up during early epochs

# %%
es = tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True, verbose=1)
mc = tf.keras.callbacks.ModelCheckpoint('model.hdf5', save_best_only=True, verbose=0)
rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=10, verbose=1)

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005
rampup_epochs = 15
sustain_epochs = 10
exp_decay = .8

def lrfn(epoch):
  if epoch < rampup_epochs:
    return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
  elif epoch < rampup_epochs + sustain_epochs:
    return max_lr
  else:
    return min_lr
    
lr = tf.keras.callbacks.LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=True)

rang = np.arange(epochs)
y = [lrfn(x) for x in rang]
plt.plot(rang, y)
print('Learning rate per epoch:')
# Out:
# Learning rate per epoch:

# %% [markdown]
# Now that we've built the model and set up our model parameters, let's train it and see what happens!

# %%
history = model.fit(
    x = train_generator,  
    validation_data = validation_generator,
    epochs = epochs,
    steps_per_epoch = steps_per_epoch,
    validation_steps = validation_steps,
    verbose=1,
    callbacks=[es, lr, mc, rlr])
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/50
# 280/280 [==============================] - 26s 92ms/step - loss: 1.6729 - accuracy: 0.4138 - val_loss: 1.0645 - val_accuracy: 0.5829 - lr: 1.0000e-05
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 1.2666666666666668e-05.
# Epoch 2/50
# 280/280 [==============================] - 25s 91ms/step - loss: 1.1333 - accuracy: 0.5875 - val_loss: 0.9972 - val_accuracy: 0.6514 - lr: 1.2667e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.5333333333333334e-05.
# Epoch 3/50
# 280/280 [==============================] - 26s 91ms/step - loss: 0.8980 - accuracy: 0.6808 - val_loss: 0.8572 - val_accuracy: 0.7143 - lr: 1.5333e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 1.8000000000000004e-05.
# Epoch 4/50
# 280/280 [==============================] - 26s 93ms/step - loss: 0.7449 - accuracy: 0.7295 - val_loss: 0.7222 - val_accuracy: 0.7600 - lr: 1.8000e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 2.066666666666667e-05.
# Epoch 5/50
# 280/280 [==============================] - 26s 91ms/step - loss: 0.6065 - accuracy: 0.7808 - val_loss: 0.7287 - val_accuracy: 0.7543 - lr: 2.0667e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 2.3333333333333336e-05.
# Epoch 6/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.5319 - accuracy: 0.8062 - val_loss: 0.6779 - val_accuracy: 0.7886 - lr: 2.3333e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 2.6000000000000002e-05.
# Epoch 7/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.4848 - accuracy: 0.8246 - val_loss: 0.6098 - val_accuracy: 0.8171 - lr: 2.6000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 2.8666666666666668e-05.
# Epoch 8/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.4058 - accuracy: 0.8500 - val_loss: 0.6449 - val_accuracy: 0.8229 - lr: 2.8667e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 3.1333333333333334e-05.
# Epoch 9/50
# 280/280 [==============================] - 26s 92ms/step - loss: 0.3553 - accuracy: 0.8719 - val_loss: 0.5191 - val_accuracy: 0.8343 - lr: 3.1333e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 3.4e-05.
# Epoch 10/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.3254 - accuracy: 0.8888 - val_loss: 0.5866 - val_accuracy: 0.8343 - lr: 3.4000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 3.6666666666666666e-05.
# Epoch 11/50
# 280/280 [==============================] - 26s 92ms/step - loss: 0.3002 - accuracy: 0.8884 - val_loss: 0.5180 - val_accuracy: 0.8514 - lr: 3.6667e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 3.933333333333334e-05.
# Epoch 12/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.2550 - accuracy: 0.9134 - val_loss: 0.5628 - val_accuracy: 0.8629 - lr: 3.9333e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 4.2000000000000004e-05.
# Epoch 13/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.2168 - accuracy: 0.9228 - val_loss: 0.6169 - val_accuracy: 0.8343 - lr: 4.2000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 4.466666666666667e-05.
# Epoch 14/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.1998 - accuracy: 0.9326 - val_loss: 0.5645 - val_accuracy: 0.8343 - lr: 4.4667e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 4.7333333333333336e-05.
# Epoch 15/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.1836 - accuracy: 0.9317 - val_loss: 0.7155 - val_accuracy: 0.8457 - lr: 4.7333e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 16/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.1621 - accuracy: 0.9464 - val_loss: 0.7032 - val_accuracy: 0.8229 - lr: 5.0000e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 17/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.1731 - accuracy: 0.9393 - val_loss: 0.6132 - val_accuracy: 0.8343 - lr: 5.0000e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 18/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.1814 - accuracy: 0.9371 - val_loss: 0.6375 - val_accuracy: 0.8514 - lr: 5.0000e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 19/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.1105 - accuracy: 0.9616 - val_loss: 0.5835 - val_accuracy: 0.8629 - lr: 5.0000e-05
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 5e-05.
# Epoch 20/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.1263 - accuracy: 0.9549 - val_loss: 0.5789 - val_accuracy: 0.8857 - lr: 5.0000e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 21/50
# 280/280 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9732
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0873 - accuracy: 0.9732 - val_loss: 0.6333 - val_accuracy: 0.8571 - lr: 1.0000e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 22/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0808 - accuracy: 0.9759 - val_loss: 0.6253 - val_accuracy: 0.8571 - lr: 1.0000e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 23/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0803 - accuracy: 0.9750 - val_loss: 0.5865 - val_accuracy: 0.8686 - lr: 1.0000e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 24/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0754 - accuracy: 0.9741 - val_loss: 0.6951 - val_accuracy: 0.8400 - lr: 1.0000e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 25/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.0564 - accuracy: 0.9848 - val_loss: 0.4921 - val_accuracy: 0.8743 - lr: 1.0000e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 26/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.0717 - accuracy: 0.9741 - val_loss: 0.6280 - val_accuracy: 0.8629 - lr: 1.0000e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 27/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0665 - accuracy: 0.9786 - val_loss: 0.7067 - val_accuracy: 0.8400 - lr: 1.0000e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 28/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.0595 - accuracy: 0.9795 - val_loss: 0.4184 - val_accuracy: 0.8686 - lr: 1.0000e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 29/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0684 - accuracy: 0.9768 - val_loss: 0.6037 - val_accuracy: 0.8343 - lr: 1.0000e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 30/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.0591 - accuracy: 0.9839 - val_loss: 0.6602 - val_accuracy: 0.8514 - lr: 1.0000e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 31/50
# 280/280 [==============================] - 25s 91ms/step - loss: 0.0527 - accuracy: 0.9835 - val_loss: 0.5361 - val_accuracy: 0.8743 - lr: 1.0000e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 32/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0503 - accuracy: 0.9866 - val_loss: 0.5746 - val_accuracy: 0.8571 - lr: 1.0000e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 33/50
# 280/280 [==============================] - 26s 92ms/step - loss: 0.0613 - accuracy: 0.9795 - val_loss: 0.5965 - val_accuracy: 0.8686 - lr: 1.0000e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 34/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0573 - accuracy: 0.9799 - val_loss: 0.6925 - val_accuracy: 0.8400 - lr: 1.0000e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 35/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0505 - accuracy: 0.9857 - val_loss: 0.5901 - val_accuracy: 0.8686 - lr: 1.0000e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 36/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0432 - accuracy: 0.9888 - val_loss: 0.4843 - val_accuracy: 0.8571 - lr: 1.0000e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 37/50
# 280/280 [==============================] - 25s 90ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 0.6842 - val_accuracy: 0.8400 - lr: 1.0000e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 38/50
# 280/280 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9848
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 280/280 [==============================] - 26s 92ms/step - loss: 0.0506 - accuracy: 0.9848 - val_loss: 0.5631 - val_accuracy: 0.8857 - lr: 1.0000e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 39/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.0484 - accuracy: 0.9879 - val_loss: 0.5421 - val_accuracy: 0.8743 - lr: 1.0000e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 40/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.0394 - accuracy: 0.9888 - val_loss: 0.5641 - val_accuracy: 0.8629 - lr: 1.0000e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 41/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.0448 - accuracy: 0.9879 - val_loss: 0.5829 - val_accuracy: 0.8686 - lr: 1.0000e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 42/50
# 280/280 [==============================] - 25s 89ms/step - loss: 0.0425 - accuracy: 0.9911 - val_loss: 0.6005 - val_accuracy: 0.8571 - lr: 1.0000e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 43/50
# 280/280 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9911Restoring model weights from the end of the best epoch.
# 280/280 [==============================] - 25s 89ms/step - loss: 0.0364 - accuracy: 0.9911 - val_loss: 0.6195 - val_accuracy: 0.8514 - lr: 1.0000e-05
# Epoch 00043: early stopping

# %% [markdown]
# # Results
# We plot the train and validation accuracy and loss to see how the model did over the epochs.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# Let's look at the last accuracy rate in terms of error.

# %%
train_err = (1-history.history['accuracy'][-1])*100
validation_err = (1-history.history['val_accuracy'][-1])*100
print("Train set error " + str(train_err))
print("Validation set error " + str(validation_err))
# Out:
# Train set error 0.892859697341919
# Validation set error 14.85714316368103

# %% [markdown]
# #Prediction
# Here we feed the test image set into the model.predict function and see how our model does.

# %%
test_datagen = ImageDataGenerator(samplewise_center = True,
                                 samplewise_std_normalization = True)

test_generator = test_datagen.flow(
    x = test_images,
    shuffle = False)

# %%
probabilities = model.predict(test_generator, steps = len(test_generator))
print(probabilities)
print(probabilities[:,0].mean()*100)
print(probabilities[:,1].mean()*100)
print(probabilities[:,2].mean()*100)
print(probabilities[:,3].mean()*100)
# Out:
# [[4.5652905e-01 1.6645327e-01 3.5412288e-01 2.2894749e-02]
#  [2.4685392e-08 2.1833409e-06 2.9626949e-07 9.9999750e-01]
#  [1.8148540e-04 4.1364467e-05 8.9758988e-03 9.9080127e-01]
#  ...
#  [1.7524377e-01 1.6399257e-02 5.2377421e-01 2.8458285e-01]
#  [9.5300376e-01 1.4887900e-04 4.3987967e-02 2.8594201e-03]
#  [4.1329996e-03 2.1205826e-02 3.5030313e-02 9.3963087e-01]]
# 22.054891288280487
# 5.811438336968422
# 44.190794229507446
# 27.942880988121033

# %%
valid_probabilities = model.predict(validation_generator, steps = len(validation_generator))
print(probabilities[:,0].mean()*100)
print(probabilities[:,1].mean()*100)
print(probabilities[:,2].mean()*100)
print(probabilities[:,3].mean()*100)
# Out:
# 22.054891288280487
# 5.811438336968422
# 44.190794229507446
# 27.94288396835327

# %%
train_probabilities = model.predict(train_generator, steps = len(train_generator))
print(probabilities[:,0].mean()*100)
print(probabilities[:,1].mean()*100)
print(probabilities[:,2].mean()*100)
print(probabilities[:,3].mean()*100)
# Out:
# 23.688289523124695
# 16.378138959407806
# 36.83198392391205
# 23.10158908367157

# %%
test = pd.read_csv('test.csv')
res = pd.DataFrame()
res['image_id'] = test['image_id']
res['healthy'] = probabilities[:, 0]
res['multiple_diseases'] = probabilities[:, 1]
res['rust'] = probabilities[:, 2]
res['scab'] = probabilities[:, 3]

# %%
res.to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, valid_probabilities)
# Out:
# 0.5262953416252789
